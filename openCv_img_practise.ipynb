# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# img_path = r'C:\Users\ArtiMarthak\Downloads\cv\dogs-vs-cats\dog_cat_DL_sample\dog_train\dog.9973.jpg'

# %%
img_path = 'C:/Users/ArtiMarthak/Downloads/cv/dogs-vs-cats/dog_cat_DL_sample/dog_train/dog.9973.jpg'

# %%
img = cv2.imread(img_path)
plt.imshow(img)

# %%
##display img
# cv2.imshow('bike_image',img)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

##necessary to be required so that the image doesn't close immediately. 
cv2.waitKey(1)
##It will run continuously until the key press.  
cv2.destroyAllWindows()

# %%
#Accessing and Modifying pixel values
pixel = img[200,200]
# print('pixel:',pixel)

#Accessing Image Properties
shape = img.shape
# print('dimension:',shape)

height = img.shape[0]
width = img.shape[1]
channel = img.shape[2]
size = img.size
# print('height: ',height)
# print('width: ',width)
# print('channel: ',channel)
# print('img size: ',size)

#Image ROI (Region of Interest)-- need to work with some areas of the image.
#Splitting and Merging Image channels
b,g,r = cv2.split(img)
# print(b)
img_roi = cv2.merge((b,g,r))
# print(img_roi)
b = img[:,:,0]
# print(b)
# plt.imshow(b)

#Making Borders for Images
border1 = cv2.copyMakeBorder(img,50,10,10,10,cv2.BORDER_REFLECT)
# plt.imshow(border1)

#Change in Image color
img_color = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# plt.imshow(img_color)
# 
# #resize
# resize_img = cv2.resize(img,1200,1000)
# plt.imshow(resize_img)

#rotate img
h,w = img.shape[:2]
center = (w/2,h/2)
angle270=270
scale=1
rotate_270 = cv2.getRotationMatrix2D(center,angle270,scale)
# plt.imshow(rotate_270)

#shape draw
rectangle = cv2.rectangle(img,(30,30),(100,100),(200,0,255),10)
# plt.imshow(rectangle)

# txtOnImg = cv2.putText(img,'Im Dog',(10,500),(0,255,255))
# plt.imshow(txtOnImg)

#Canny Edge Detection
# edges = cv2.Canny(img,100,100)
# plt.imshow(edges)

#removing the noise. It is generally used to eliminate the high-frequency content such as noise, edges in the image
# doBlur = cv2.blur(img,(3,3))
# plt.imshow(doBlur)

# doMedianBlur = cv2.medianBlur(img,5)
# plt.imshow(doMedianBlur)

# doGaussianBlur = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)
# plt.imshow(doGaussianBlur)

# doBoxFilterBlur = cv2.boxFilter(img,0,(5,5),img,(-1,-1),False,cv2.BORDER_DEFAULT)
# plt.imshow(doBoxFilterBlur)

#enhance brightness and contrast.
# doFilter2D = cv2.filter2D(img,-1,np.ones((5,5),np.float32)/25)
# plt.imshow(doFilter2D)

# doBilateralFilter = cv2.bilateralFilter(img,9,75,25)
# plt.imshow(doBoxFilterBlur)

#Image Thresholdthreshold is converted everything to white or black.0-125black 125-255white.
#threshold is that more simplify the visual data for analysis.convert the image into gray-scale.
# ret,threshold = cv2.threshold(img,62,255,cv2.THRESH_BINARY)
# plt.imshow(threshold)

#Contours are defined as a curve joining all the continuous points (along the boundary)


#write img
# cv2.imwrite('C:/Users/ArtiMarthak/Downloads/cv/dog11.jpg',rectangle)
